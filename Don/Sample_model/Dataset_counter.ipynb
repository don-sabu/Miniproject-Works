# %%
import os
from matplotlib import pyplot as plt

# %%
def direrctory_finder(path):
    directory = []
    for dir in os.listdir(path):
        if os.path.isdir(path+dir):
            directory.append(dir)
    return directory

# %%
def dataset_counter(path):
    directories = direrctory_finder(path)
    count = {}
    for dir in directories:
        dirPath = path + dir + '/'
        count[dir] = len(os.listdir(dirPath))
    return count

# %%
def show_dataset_count(path):
    data_count = dataset_counter(path)
    x = data_count.keys()
    y = data_count.values()
    plt.bar(x,y)
    plt.show()

# %%
show_dataset_count("/Project/Coding/20240204 Miniproject Works/Miniproject-Works/_Dataset/Segmented/Single_digit_with_half/")
