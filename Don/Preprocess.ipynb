# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("sample_image02.jpeg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img)

# %%
plt.imshow(th3)

# %%
cv2.imwrite("preprocess.jpeg",th3)
# Out:
# True

# %%
def preprocess(img):
    blr_img = cv2.medianBlur(img,5)
    return cv2.adaptiveThreshold(blr_img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
